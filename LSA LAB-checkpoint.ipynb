# %%
from sklearn.datasets import fetch_20newsgroups
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0gx','rgb','style','51','spacing','text','helvetica','size','family','space','arial','height','lindent','letter','line','none','sans','serif','transform','line','variant','weight','times','strong','new','video','title','white','word','letter','roman','Opt','16','color','12','14','21','neve','apple','class',])

# %%
#nltk.download()

# %%
corpus[0]
# Out:
# u"From: writingctr@leo.bsuvc.bsu.edu\nSubject: Re: CUB fever.\nOrganization: Ball State University, Muncie, In - Univ. Computing Svc's\nLines: 21\n\n\nIn article <kingoz.735285670@camelot>, kingoz@camelot.bradley.edu (Orin Roth) writes:\n> \n>    CUB fever is hitting me again. I'm beginning to think they have a \n>    chance this year. (what the heck am i thinking?)\n>    Sorry. Just a moment of incompetence.\n>    I'll be ok. Really. \n>    Orin.\n>    Bradley U.\n> \n> --\n> I'm really a jester in disguise!                                   \nI hear ya!  Then again, we must remember that we are indeed Cub fans, and\nthat the Cubs will eventually blow it.  After all, the Cubs are the easiest\nteam in the National League to root for.  No Pressure.  You know they will\nlose eventually.  Oh well, I suppose we must have faith.  After all, they\ndo look pretty good, and they don't even have Sandberg back yet.  \n\nCUBS IN '93!!!!!\n\nCHA\n"

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x190051 sparse matrix of type '<type 'numpy.float64'>'
# 	with 235 stored elements in Compressed Sparse Row format>

# %%
print X[0]
# Out:
#   (0, 51475)	0.0734463096625
#   (0, 189323)	0.0734463096625
#   (0, 28954)	0.0734463096625
#   (0, 146580)	0.0734463096625
#   (0, 64428)	0.0734463096625
#   (0, 77938)	0.0734463096625
#   (0, 133180)	0.0734463096625
#   (0, 103446)	0.0734463096625
#   (0, 66814)	0.0734463096625
#   (0, 114541)	0.0734463096625
#   (0, 163286)	0.0734463096625
#   (0, 181094)	0.0734463096625
#   (0, 119646)	0.0734463096625
#   (0, 64564)	0.0734463096625
#   (0, 103940)	0.0734463096625
#   (0, 95553)	0.0734463096625
#   (0, 133095)	0.0734463096625
#   (0, 143744)	0.0734463096625
#   (0, 98147)	0.0734463096625
#   (0, 115182)	0.0734463096625
#   (0, 165645)	0.0734463096625
#   (0, 59684)	0.0734463096625
#   (0, 51515)	0.0734463096625
#   (0, 35722)	0.0734463096625
#   (0, 64554)	0.0734463096625
#   :	:
#   (0, 143978)	0.0551931192048
#   (0, 122313)	0.11038623841
#   (0, 37511)	0.0989842910659
#   (0, 40681)	0.104524831508
#   (0, 16529)	0.0734463096625
#   (0, 94964)	0.11038623841
#   (0, 25779)	0.0160794683389
#   (0, 100827)	0.010248916482
#   (0, 163875)	0.0606840380211
#   (0, 48159)	0.0387972930629
#   (0, 175248)	0.0391426583255
#   (0, 114339)	0.0606840380211
#   (0, 175284)	0.0179368326547
#   (0, 159048)	0.0372269139097
#   (0, 29476)	0.0306118463788
#   (0, 121700)	0.0102695385529
#   (0, 68355)	0.124508834349
#   (0, 51397)	0.160868220155
#   (0, 137215)	0.0126673855948
#   (0, 161848)	0.0101872995629
#   (0, 60184)	0.023728059338
#   (0, 38751)	0.0505117257066
#   (0, 38761)	0.0505117257066
#   (0, 99173)	0.0494921455329
#   (0, 186822)	0.0734463096625

# %%
X.shape
# Out:
# (994, 190051)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
lsa.components_[0]
# Out:
# array([ 0.01597904,  0.00498283,  0.00080901, ...,  0.00102609,
#         0.00102609,  0.00102609])

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# think
#
# year
#
# runs
#
# cs
#
# could
#
# duke
#
# better
#
# win
#
# team
#
# article
#
# Concept 2:
# edu
#
# article
#
# 00 00 gmt
#
# posting
#
# cs
#
# 00 00 baltimore
#
# go
#
# 00 00 00
#
# could
#
# writes
#
# Concept 3:
# com
#
# university
#
# 00 00 00
#
# season
#
# host
#
# anyone
#
# usa
#
# writes article
#
# nntp
#
# may
#
# Concept 4:
# 00
#
# 00 00
#
# morris
#
# 00 00 00
#
# pitching
#
# better
#
# way
#
# doesn
#
# like
#
# nntp posting
#
# Concept 5:
# 00
#
# 00 00
#
# 00 00 01
#
# would
#
# also
#
# time
#
# 00 00 00
#
# 00 00 000
#
# world
#
# lines
#
# Concept 6:
# 00
#
# 00 00
#
# game
#
# com
#
# 00 00 gmt
#
# 00 00 00
#
# 00 00 cleveland
#
# cornell
#
# article
#
# 00 00 chicago
#
# Concept 7:
# game
#
# one
#
# cs
#
# article
#
# runs
#
# three
#
# win
#
# 10
#
# netcom
#
# games
#
# Concept 8:
# 00
#
# organization
#
# 00 00
#
# think
#
# clutch
#
# morris
#
# win
#
# run
#
# university
#
# won
#
# Concept 9:
# writes
#
# edu
#
# think
#
# cs
#
# morris
#
# ca
#
# first
#
# baseball
#
# 00 00 00
#
# article
#
# Concept 10:
# team
#
# com
#
# game
#
# 00 00 000
#
# cs
#
# fan
#
# also
#
# bonds
#
# pitching
#
# made
#
# Concept 11:
# com
#
# cs
#
# subject re
#
# lines
#
# morris
#
# 00
#
# better
#
# subject
#
# netcom com
#
# 00 00
#
# Concept 12:
# game
#
# com
#
# organization
#
# nntp posting
#
# first
#
# subject re
#
# posting
#
# nntp posting host
#
# posting host
#
# runs
#
# Concept 13:
# team
#
# posting
#
# 00 00 baltimore
#
# game
#
# edu
#
# much
#
# host
#
# 00 00 01
#
# jewish
#
# see
#
# Concept 14:
# year
#
# nntp posting host
#
# posting host
#
# last
#
# one
#
# hit
#
# com
#
# nntp
#
# first
#
# years
#
# Concept 15:
# edu
#
# university
#
# one
#
# 00 00 cleveland
#
# subject re
#
# team
#
# well
#
# article
#
# two
#
# john
#
# Concept 16:
# com
#
# baseball
#
# 00 00 01
#
# good
#
# 00 00 000
#
# posting
#
# make
#
# home
#
# could
#
# time
#
# Concept 17:
# year
#
# well
#
# baseball
#
# cs
#
# would
#
# 00 00 american
#
# could
#
# game
#
# nntp posting
#
# first
#
# Concept 18:
# year
#
# posting
#
# braves
#
# subject re
#
# much
#
# season
#
# news
#
# university
#
# game
#
# 00 00 detroit
#
# Concept 19:
# writes
#
# good
#
# posting
#
# com
#
# team
#
# 00 00 detroit
#
# better
#
# 00 00 cleveland
#
# think
#
# two
#
# Concept 20:
# one
#
# like
#
# first
#
# players
#
# 00 00 detroit
#
# runs
#
# also
#
# three
#
# reply
#
# posting
#
# Concept 21:
# subject re
#
# like
#
# cs
#
# host
#
# 00 00 detroit
#
# even
#
# 00 00 000
#
# 00 00 colorado
#
# nntp
#
# roger
#
# Concept 22:
# 00 00 detroit
#
# writes
#
# baseball
#
# know
#
# organization
#
# host
#
# article
#
# re
#
# game
#
# subject
#
# Concept 23:
# article
#
# 00 00 baltimore
#
# baseball
#
# like
#
# last
#
# games
#
# subject
#
# 00 00 gmt
#
# ca
#
# year
#
# Concept 24:
# 00 00 detroit
#
# subject
#
# 00 00 00
#
# 00 00 01
#
# like
#
# game
#
# nntp posting
#
# one
#
# 00 00 cleveland
#
# writes
#
# Concept 25:
# edu
#
# like
#
# subject
#
# re
#
# com
#
# would
#
# game
#
# time
#
# university
#
# year
#
# Concept 26:
# writes
#
# lines
#
# 00 00 gmt
#
# year
#
# 00 00 american
#
# subject re
#
# 00 00 detroit
#
# know
#
# com
#
# edu

# %%
corpus[10]
# Out:
# u'From: hamkins@geisel.csl.uiuc.edu (Jon Hamkins)\nSubject: Re: Triva question on Bosio\'s No-hitter\nOrganization: Center for Reliable and High-Performance Computing, University of Illinois at Urbana-Champaign\nLines: 16\nNNTP-Posting-Host: grinch.csl.uiuc.edu\n\nwall@cc.swarthmore.edu (Matthew Wall) writes:\n\n>I don\'t actually have the answer to this one.\n\n>Bosio, after walking the first two batters, retired 27-straight for a\n>"back-end" perfect game.\n\nWell, there were 27 outs in a row with no hits or walks in between, but\nreally, he only retired 26 batters in a row.  The first out of the game\nwas the front end of a double play.  Still counts as a back-end perfect\ngame in my book, though. \n\nCongrats to Chris Bosio.  Too bad the Brewers couldn\'t hold on to him.\n\n     ----Jon Hamkins  (hamkins@uiuc.edu)\n         University of Illionois\n'

# %%
vectorizer = TfidfVectorizer(stop_words=stopset,use_idf=True,ngram_range=(1,3))
X=vectorizer.fit_transform(corpus)

# %%
X[10]
# Out:
# <1x190051 sparse matrix of type '<type 'numpy.float64'>'
# 	with 238 stored elements in Compressed Sparse Row format>

# %%
print X[10]
# Out:
#   (0, 61447)	0.0644942438838
#   (0, 174457)	0.0644942438838
#   (0, 80826)	0.0644942438838
#   (0, 80822)	0.0644942438838
#   (0, 93106)	0.0644942438838
#   (0, 85160)	0.0644942438838
#   (0, 50224)	0.0644942438838
#   (0, 38193)	0.0644942438838
#   (0, 29010)	0.0644942438838
#   (0, 36965)	0.0644942438838
#   (0, 44156)	0.0644942438838
#   (0, 48449)	0.0644942438838
#   (0, 168821)	0.0644942438838
#   (0, 36760)	0.0644942438838
#   (0, 72773)	0.0644942438838
#   (0, 125488)	0.0644942438838
#   (0, 50359)	0.0644942438838
#   (0, 160308)	0.0644942438838
#   (0, 129271)	0.0644942438838
#   (0, 58151)	0.0644942438838
#   (0, 62486)	0.0644942438838
#   (0, 72084)	0.0644942438838
#   (0, 72976)	0.0644942438838
#   (0, 69599)	0.0644942438838
#   (0, 144065)	0.0644942438838
#   :	:
#   (0, 175990)	0.0402690777495
#   (0, 88240)	0.038890105592
#   (0, 174428)	0.103115166599
#   (0, 117369)	0.0161841592435
#   (0, 132032)	0.0161841592435
#   (0, 117368)	0.0161841592435
#   (0, 9032)	0.0706971533728
#   (0, 8733)	0.0351781789266
#   (0, 83169)	0.0329487911727
#   (0, 86046)	0.0161639887458
#   (0, 132025)	0.0160638128735
#   (0, 117363)	0.0161841592435
#   (0, 69428)	0.0430386720117
#   (0, 162152)	0.0115701962453
#   (0, 28600)	0.0508137182615
#   (0, 180637)	0.0224050009986
#   (0, 138371)	0.0241911325966
#   (0, 185887)	0.0136511450206
#   (0, 100827)	0.00899971859949
#   (0, 48159)	0.0340684520751
#   (0, 175284)	0.0315011731713
#   (0, 121700)	0.00901782713181
#   (0, 137215)	0.0111234105522
#   (0, 161848)	0.00894561191088
#   (0, 60184)	0.0416718893807

# %%
X.shape
# Out:
# (994, 190051)

# %%
lsa=TruncatedSVD(n_components=27,n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=27, n_iter=100,
#        random_state=None, tol=0.0)

# %%
terms=vectorizer.get_feature_names()
for i, comp in enumerate (lsa.components_):
    termsInComp=zip(terms,comp)
    sortedTerms=sorted(termsInComp,key=lambda X:X[1],reverse = True)[:10]
    print "Concept %d:"%i
    for term in sortedTerms:
        print term[0]
        print""
# Out:
# Concept 0:
# edu
#
# com
#
# year
#
# writes
#
# team
#
# would
#
# game
#
# article
#
# re
#
# cs
#
# Concept 1:
# cs
#
# ca
#
# organization university
#
# subject re
#
# organization
#
# writes
#
# many
#
# might
#
# even
#
# could
#
# Concept 2:
# edu
#
# cs
#
# posting
#
# university
#
# one
#
# gant
#
# nntp posting host
#
# posting host
#
# host
#
# nntp
#
# Concept 3:
# com
#
# game
#
# posting
#
# gant
#
# one
#
# hirschbeck
#
# think
#
# back
#
# subject re
#
# nntp posting host
#
# Concept 4:
# year
#
# 00
#
# cs
#
# posting
#
# 00 00 00
#
# runs
#
# 00 00
#
# last
#
# good
#
# think
#
# Concept 5:
# 00
#
# 00 00
#
# get
#
# organization
#
# subject
#
# team
#
# nntp
#
# edu
#
# cs
#
# university
#
# Concept 6:
# 00
#
# 00 00
#
# would
#
# players
#
# 00 00 00
#
# re
#
# article
#
# 00 00 american
#
# news
#
# won
#
# Concept 7:
# year
#
# know
#
# 00
#
# one
#
# 00 00 chicago
#
# host
#
# 00 00
#
# game
#
# players
#
# team
#
# Concept 8:
# team
#
# players
#
# ca
#
# two
#
# ll
#
# last
#
# year
#
# cs
#
# one
#
# university
#
# Concept 9:
# university
#
# year
#
# games
#
# organization
#
# host
#
# good
#
# last
#
# organization university
#
# nntp
#
# 00 00 000
#
# Concept 10:
# organization
#
# team
#
# games
#
# edu
#
# subject
#
# 00 00 detroit
#
# much
#
# come
#
# university
#
# 00 00 gmt
#
# Concept 11:
# won
#
# players
#
# cs
#
# time
#
# get
#
# edu
#
# 00 00 american
#
# organization university
#
# 00 00 cleveland
#
# nntp
#
# Concept 12:
# com
#
# year
#
# baseball
#
# subject
#
# roger
#
# 00 00 detroit
#
# posting
#
# 10
#
# 00 00 cleveland
#
# 00 00 000
#
# Concept 13:
# think
#
# hit
#
# well
#
# lines
#
# games
#
# get
#
# bad
#
# even
#
# also
#
# people
#
# Concept 14:
# first
#
# time
#
# 10
#
# right
#
# point
#
# back
#
# steve
#
# mike
#
# writes article
#
# 20
#
# Concept 15:
# year
#
# com
#
# lines
#
# 00 00 colorado
#
# team
#
# many
#
# host
#
# would
#
# get
#
# still
#
# Concept 16:
# lines
#
# subject re
#
# re
#
# 10
#
# 00 00 chicago
#
# organization
#
# know
#
# time
#
# 00 00 colorado
#
# best
#
# Concept 17:
# think
#
# 00 00 cleveland
#
# cs
#
# know
#
# organization
#
# pitcher
#
# time
#
# win
#
# year
#
# much
#
# Concept 18:
# baseball
#
# lines
#
# 00 00 colorado
#
# 00 00 cleveland
#
# last
#
# 00 00 baltimore
#
# team
#
# players
#
# say
#
# braves
#
# Concept 19:
# time
#
# host
#
# 00 00 colorado
#
# nntp posting
#
# com
#
# nntp posting host
#
# posting host
#
# university
#
# nntp
#
# game
#
# Concept 20:
# game
#
# time
#
# com
#
# last
#
# games
#
# 00 00 cleveland
#
# one
#
# 00 00 chicago
#
# 00 00 detroit
#
# pitching
#
# Concept 21:
# good
#
# organization
#
# lines
#
# first
#
# com
#
# players
#
# re
#
# 00 00 american
#
# say
#
# nntp posting
#
# Concept 22:
# com
#
# cs
#
# baseball
#
# would
#
# 00
#
# subject re
#
# 00 00 detroit
#
# players
#
# 00 00
#
# article
#
# Concept 23:
# 00 00 gmt
#
# nntp posting
#
# nntp posting host
#
# posting host
#
# nntp
#
# 00 00 chicago
#
# would
#
# players
#
# year
#
# cs
#
# Concept 24:
# university
#
# com
#
# article
#
# lines
#
# go
#
# play
#
# win
#
# much
#
# get
#
# could
#
# Concept 25:
# 00 00 01
#
# article
#
# host
#
# re
#
# subject
#
# braves
#
# could
#
# like
#
# 00 00 baltimore
#
# much
#
# Concept 26:
# article
#
# writes
#
# organization
#
# one
#
# subject
#
# players
#
# 00 00 000
#
# year
#
# game
#
# edu
